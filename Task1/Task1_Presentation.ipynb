# %% [markdown]
# # Task 1 – Data Cleaning & Formatting
#
# **Objective:**
# To clean and format the client-provided survey dataset into an SPSS-ready `.sav` file for Q import.
#
# **Tools Used:**
# Python (pandas, numpy, pyreadstat)
#
# **Overview of Steps**
# 1. Remove invalid or incomplete records
# 2. Process multi-response questions
# 3. Convert text labels to numeric codes
# 4. Apply skip logic (Q1_99)
# 5. Rename and reorder columns
# 6. Create 'Wave' variable
# 7. Add variable and value labels
# 8. Export to `.sav`

# %% [markdown]
# ## Step 0 – Import Packages and Load Data
#
# Before starting the data cleaning process, I first import all necessary Python libraries and my custom functions.
#
# ###  Imported Libraries
# - **pandas** – used for reading and transforming the Excel dataset into a DataFrame.
# - **numpy** – provides numerical operations such as handling missing values (`NaN`) and creating new columns efficiently.
# - **pyreadstat** – enables exporting the cleaned dataset to SPSS (`.sav`) format with correct labels and value codes.
#
# ### Importing Custom Functions from `Task1.py`
# The script `Task1.py` contains all the cleaning functions I previously built.
# By importing them here, I can execute each step interactively in Jupyter Notebook and show how the dataset changes after every operation.
#
# Functions imported:
# - `remove_invalid_cases()` – removes logic errors and incomplete rows
# - `process_multiresponse_questions()` – splits multi-response questions into binary columns
# - `convert_labels_to_codes()` – maps text answers to numeric codes
# - `apply_q1_99_skip_logic()` – applies skip rules for respondents selecting “None of these”  ( (:P)Forgot to find this error logic until checking)
# - `rename_and_reorder_columns()` – renames variables and adjusts their order
# - `create_wave_variable()` – creates the weekly ‘Wave’ variable from `CompletedDate`
# - `create_labels()` – builds variable and value label dictionaries for SPSS
# - `save_to_spss()` – exports the cleaned dataset with labels into `.sav`
#
# ### Loading the Raw Dataset
# The raw Excel file, **`EXAMPLE DATA FILE.xlsx`**, is then read using `pandas.read_excel()` to inspect its structure and confirm that all expected columns are present before cleaning begins.

# %%
import pandas as pd
import numpy as np
import pyreadstat

from Task1 import (
    remove_invalid_cases,
    process_multiresponse_questions,
    convert_labels_to_codes,
    apply_q1_99_skip_logic,
    rename_and_reorder_columns,
    create_wave_variable,
    create_labels,
    save_to_spss
)

# Load the raw data
df = pd.read_excel("EXAMPLE DATA FILE.xlsx")
df.head()
# Out:
#    ID What is your gender? What is your age?  What is your postcode?  \
# 0  76               Female               65+                    6128
# 1  78               Female               65+                    6002
# 2  79               Female             35-44                    6289
# 3  82               Female             55-64                    6122
# 4  85               Female             25-34                    6162
#
#   Which of the following brands of electricity providers are you aware of?  \
# 0                   Synergy; AGL; Origin; Red Energy
# 1                                      None of these
# 2  Synergy; Western Power; Origin; Horizon Power;...
# 3                         AGL; Origin; Horizon Power
# 4                                      None of these
#
#   Which of the following brands of electricity providers are you aware of? (Other (please specify))  \
# 0
# 1
# 2                                               ATCO
# 3
# 4
#
#   And which ONE of these brands is your main provider?   \
# 0                                             Origin
# 1                                             Origin
# 2                                         Red Energy
# 3                                             Origin
# 4                                             Origin
#
#   And which ONE of these brands is your main provider? (Other (please specify))  \
# 0
# 1
# 2
# 3
# 4
#
#   Thinking about ‘Origin’, how favourable is your overall impression of them?  \
# 0                                    Very favourable
# 1                                  Very unfavourable
# 2                                    Very favourable
# 3                                            Neutral
# 4                                    Very favourable
#
#   How likely are you to recommend ‘Origin’ to friends or family?  ...  \
# 0                                                  1              ...
# 1                                                  7              ...
# 2                                                  6              ...
# 3                                                  2              ...
# 4                                                  6              ...
#
#   How would you rate ‘Origin’ on each of the following? (Innovation)  \
# 0                                               Fair
# 1                                          Very poor
# 2                                          Excellent
# 3                                               Fair
# 4                                               Fair
#
#   In the past 12 months, have you seen or heard any advertising for ‘Origin’?  \
# 0                                         Don't know
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Where did you see or hear advertising for ‘Origin’?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  TV; Online / Social media; Outdoor (billboards...
#
#   Where did you see or hear advertising for ‘Origin’? (Other (please specify))  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of the following best describes your current work status?  \
# 0                                            Retired
# 1                                            Student
# 2                    Unemployed and looking for work
# 3                                            Retired
# 4                                  Working full time
#
#   Which of the following best describes your current work status? (Other (please specify))  \
# 0
# 1
# 2
# 3
# 4
#
#   Which of the following best describes your total annual household income?  \
# 0                                    $60,000–$89,999
# 1                                    $60,000–$89,999
# 2                                    $60,000–$89,999
# 3                                   $90,000–$119,999
# 4                                  Less than $30,000
#
#   Which of the following best describes your household structure?  \
# 0                      Group household / share house
# 1                Single parent with children at home
# 2                                Couple, no children
# 3                                Couple, no children
# 4                                Single, no children
#
#   Which of the following best describes your household structure? (Other (please specify))  \
# 0
# 1
# 2
# 3
# 4
#
#   CompletedDate
# 0    2025-08-04
# 1    2025-08-04
# 2    2025-08-04
# 3    2025-08-04
# 4    2025-08-04
#
# [5 rows x 24 columns]
